# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3], [2, 4, 3])

# %%
x = np.arange(-10, 10)
plt.figure(figsize = (12, 6))
plt.subplot(1, 2, 1)
plt.plot(x, x**2)

plt.subplot(1, 2, 2)
plt.scatter(x, x**2)

# %%
plot_obj = plt.subplots(nrows = 2, ncols = 3, figsize = (14, 6))
fig, ((a, b, c), (d, e, f)) = plot_obj

# %%
fig.savefig("nonsense.png")
